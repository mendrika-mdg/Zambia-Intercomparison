# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.imshow(np.load("/gws/nopw/j04/wiser_ewsa/mrakotomanga/Intercomparison/zcast/ensemble_nowcasts/t6/202401/12/zcast_mean_20240117_1245.npy"))

# %%
import torch

# %%
plt.imshow(torch.load("/gws/nopw/j04/wiser_ewsa/mrakotomanga/Intercomparison/combined_nowcasts/ensemble/t1/20200110_2245.pt", weights_only=False)['netncc'])
